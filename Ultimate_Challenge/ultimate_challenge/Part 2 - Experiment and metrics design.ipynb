# %%
import json
import numpy as np
import pandas as pd

# %%
df = pd.read_json('ultimate_data_challenge.json')

# %%
df.head()
# Out:
#              city  trips_in_first_30_days signup_date  avg_rating_of_driver  \
# 0  King's Landing                       4  2014-01-25                   4.7
# 1         Astapor                       0  2014-01-29                   5.0
# 2         Astapor                       3  2014-01-06                   4.3
# 3  King's Landing                       9  2014-01-10                   4.6
# 4      Winterfell                      14  2014-01-27                   4.4
#
#    avg_surge last_trip_date    phone  surge_pct  ultimate_black_user  \
# 0       1.10     2014-06-17   iPhone       15.4                 True
# 1       1.00     2014-05-05  Android        0.0                False
# 2       1.00     2014-01-07   iPhone        0.0                False
# 3       1.14     2014-06-29   iPhone       20.0                 True
# 4       1.19     2014-03-15  Android       11.8                False
#
#    weekday_pct  avg_dist  avg_rating_by_driver
# ...

# %% [markdown]
# For a full context of the situation I will copy the question below
#
# The neighboring cities of Gotham and Metropolis have complementary circadian rhythms: on
# weekdays, Ultimate Gotham is most active at night, and Ultimate Metropolis is most active
# during the day. On weekends, there is reasonable activity in both cities.
# However, a toll bridge, with a two­way toll, between the two cities causes driver partners to tend
# to be exclusive to each city. The Ultimate managers of city operations for the two cities have
# proposed an experiment to encourage driver partners to be available in both cities, by
# reimbursing all toll costs.
# 1. What would you choose as the key measure of success of this experiment in
# encouraging driver partners to serve both cities, and why would you choose this metric?
# 2. Describe a practical experiment you would design to compare the effectiveness of the
# proposed change in relation to the key measure of success. Please provide details on:
#
#     a. how you will implement the experiment
#
#     b. what statistical test(s) you will conduct to verify the significance of the
# observation
#
#     c. how you would interpret the results and provide recommendations to the city
# operations team along with any caveats.

# %% [markdown]
# 1. if No new features were to be added to the dataset once this experiment has commenced, I would have to say that the an increase of the weekday percentage of trips in Gotham and Metropolis would be the key measure. This is because, as per the information statement, the cities are equally active on weekends and by seeing a general increase of weekday_pct in these two cities would mean that the emotion of the drivers to take these trips would have increased. Again this is assuming that no new features would be added. The best feature would be to track how many weekday trips from one city to the next had taken place during the experiment vs. before the experiment. But as far as I can tell this information is not available with our current dataset.
# 2. a. Again, assuming we could not add gather any new types of data(i.e, amount of trips betweeen cities, we would first freeze our dataset as is right before the experiment takes place. This would give us our numbers before the experiment begins. After an ample amount of time we will take another freeze of our data and first, elimanate all users that have a last trip date before our experiment began as well as eliminate all users that do not have Gotham or Metropolis listed as their main cities. Then we can compare the weekday percentage from before the experiment to after the experiment and see if there is any statistical significance between the two.
#
# b. to initialize, it would be easiest to simply look at the mean between the two datasets. If the post-experiment mean weekday percentage is higher, than we at the very least say that as of beginning the experiemnt the mean weekday pct as increased. if it decreases or stays the same, then we can very safely say that this new experiment yielded no changes.
#
# c. We could interpret the results as a guide for further value provided by the company. By looking for roadblocks put into place by city ordinances, like tolls, and addressing them, we could expect to see higher frequencies of transactions with the companies added value to customers. If there was no such changes, we may reccomend to the city operations team that looking to provide multi-city travel options are not worth the effort until a new experiment is tested.
